# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

import pandas as pd
import mglearn
# %matplotlib inline

# %%
df = pd.read_csv('data/MoviesOnStreamingPlatforms_updated.csv').fillna('0')

df['Age'] = df['Age'].str.replace('+','').replace('all','0').astype(int)
df['Rotten Tomatoes'] = df['Rotten Tomatoes'].str.replace('%','').astype(int)

df.head()
# Out:
# c:\users\josue\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
#    ID                           Title  Year  Age IMDb  Rotten Tomatoes  \
# 0   1                       Inception  2010   13  8.8               87
# 1   2                      The Matrix  1999   18  8.7               87
# 2   3          Avengers: Infinity War  2018   13  8.5               84
# 3   4              Back to the Future  1985    7  8.5               96
# 4   5  The Good, the Bad and the Ugly  1966   18  8.8               97
#
#    Netflix  Hulu  Prime Video  Disney+  Type                       Directors  \
# 0        1     0            0        0     0               Christopher Nolan
# ...

# %%
features = ['Age','Runtime']

scaler = MinMaxScaler()
X = df[features].values
X_scaled = scaler.fit_transform(X)
